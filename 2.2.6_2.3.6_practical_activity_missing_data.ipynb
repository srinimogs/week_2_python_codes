# %%
import pandas as pd

# %% [markdown]
# # To Import the excel file in Jupyter

# %%
mov_list = pd.read_excel('movies.xlsx')
mov_list
# Out:
#                                 Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  2010  13+   8.8             0.87
# 1                          The Matrix  1999  18+   8.7             0.87
# 2              Avengers: Infinity War  2018  13+   8.5             0.84
# 3                  Back to the Future  1985   7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  1966  18+   8.8             0.97
# ...                               ...   ...  ...   ...              ...
# 16739       The Ghosts of Buxley Hall  1980  NaN   6.2              NaN
# 16740                  The Poof Point  2001   7+   4.7              NaN
# 16741           Sharks of Lost Island  2013  NaN   5.7              NaN
# 16742              Man Among Cheetahs  2017  NaN   6.6              NaN
# 16743                In Beaver Valley  1950  NaN   NaN              NaN
#
#                             Directors                            Genres  \
# ...

# %% [markdown]
# # to import CSV file into Jupyter

# %%
ott_list = pd.read_csv('ott.csv')
ott_list
# Out:
#           ID  Netflix  Hulu  Prime Video  Disney+
# 0          1        0     0            1        0
# 1          2        0     1            0        0
# 2          3        0     0            1        0
# 3          4        1     0            0        0
# 4          5        0     0            1        0
# ...      ...      ...   ...          ...      ...
# 16739  16740        0     0            1        0
# 16740  16741        0     0            1        0
# 16741  16742        0     0            1        0
# 16742  16743        0     0            1        0
# 16743  16744        1     0            0        0
#
# [16744 rows x 5 columns]

# %% [markdown]
# # to print data type of the excel file

# %%
print(mov_list.dtypes)
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes    float64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %% [markdown]
# # to show data type for the CSV file

# %%
print(ott_list.dtypes)
# Out:
# ID             int64
# Netflix        int64
# Hulu           int64
# Prime Video    int64
# Disney+        int64
# dtype: object

# %% [markdown]
# # to show column names in both files

# %%
print(mov_list.columns)
print(ott_list.columns)
# Out:
# Index(['Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')
# Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')

# %% [markdown]
# # to show columns with numeric values

# %%
movie = mov_list.select_dtypes('number')
movie
# Out:
#        Year  IMDb  Rotten Tomatoes  Runtime
# 0      2010   8.8             0.87    148.0
# 1      1999   8.7             0.87    136.0
# 2      2018   8.5             0.84    149.0
# 3      1985   8.5             0.96    116.0
# 4      1966   8.8             0.97    161.0
# ...     ...   ...              ...      ...
# 16739  1980   6.2              NaN    120.0
# 16740  2001   4.7              NaN     90.0
# 16741  2013   5.7              NaN      NaN
# 16742  2017   6.6              NaN      NaN
# 16743  1950   NaN              NaN     32.0
#
# [16744 rows x 4 columns]

# %% [markdown]
# # drop the column with non-numeric values

# %%
mov_list = mov_list.drop('Year', axis=1)
mov_list
# Out:
#                                 Title  Age  IMDb  Rotten Tomatoes  \
# 0                           Inception  13+   8.8             0.87
# 1                          The Matrix  18+   8.7             0.87
# 2              Avengers: Infinity War  13+   8.5             0.84
# 3                  Back to the Future   7+   8.5             0.96
# 4      The Good, the Bad and the Ugly  18+   8.8             0.97
# ...                               ...  ...   ...              ...
# 16739       The Ghosts of Buxley Hall  NaN   6.2              NaN
# 16740                  The Poof Point   7+   4.7              NaN
# 16741           Sharks of Lost Island  NaN   5.7              NaN
# 16742              Man Among Cheetahs  NaN   6.6              NaN
# 16743                In Beaver Valley  NaN   NaN              NaN
#
#                             Directors                            Genres  \
# 0                   Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
q1 = mov_list.quantile(0.25)
q3 = mov_list.quantile(0.75)
print(q1)
print(q3)
# Out:
# IMDb                5.10
# Rotten Tomatoes     0.44
# Runtime            82.00
# Name: 0.25, dtype: float64
# IMDb                 6.90
# Rotten Tomatoes      0.88
# Runtime            104.00
# Name: 0.75, dtype: float64

# %%
iqr = q3 - q1
print(iqr)
# Out:
# IMDb                1.80
# Rotten Tomatoes     0.44
# Runtime            22.00
# dtype: float64

# %% [markdown]
# # show variation of data in the excel file

# %%
mov_list.describe()
# Out:
#                IMDb  Rotten Tomatoes       Runtime
# count  16173.000000      5158.000000  16152.000000
# mean       5.902751         0.654285     93.413447
# std        1.347867         0.266145     28.219222
# min        0.000000         0.020000      1.000000
# 25%        5.100000         0.440000     82.000000
# 50%        6.100000         0.710000     92.000000
# 75%        6.900000         0.880000    104.000000
# max        9.300000         1.000000   1256.000000

# %%
fitness = pd.read_csv('daily_activity.csv')
fitness.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fitness_na = fitness[fitness.isna().any(axis=1)]
fitness_na.shape
# Out:
# (0, 15)

# %%
fitness_raw = pd.read_csv('daily_activity_raw.csv')
fitness_raw.head()
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366   04/12/2016     13162.0       8.500000         8.500000
# 1  1503960366    4/13/2016      1735.0       6.970000         6.970000
# 2  1503960366    4/14/2016       146.0       6.740000         6.740000
# 3  1503960366    4/15/2016      9762.0       6.282988         6.282988
# 4  1503960366    4/16/2016     12669.0       8.160000         8.160000
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       NaN            1.880000                  0.551193
# 1                       NaN            1.575245                  0.690000
# 2                       NaN            2.445722                  0.459646
# 3                       NaN            2.141494                  1.260000
# 4                       NaN            2.713815                  0.500000
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %%
fitness_raw_na = fitness_raw[fitness_raw.isna().any(axis=1)]
fitness_raw_na
fitness_raw_na.shape
# Out:
# (937, 15)
